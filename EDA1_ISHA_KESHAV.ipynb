# %% [markdown]
# <a href="https://colab.research.google.com/github/keshavisha/Music-Genre/blob/main/EDA1_ISHA_KESHAV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("features_30_sec.csv")

# %%
df=df.drop("filename", axis="columns")
df=df.drop("length", axis="columns")

# %%
df_blues=df.iloc[:100,43]
df_classical=df.iloc[100:200,43]
df_country=df.iloc[200:300,43]
df_disco=df.iloc[300:400,43]
df_hiphop=df.iloc[400:500,43]
df_jazz=df.iloc[500:600,43]
df_metal=df.iloc[600:700,43]
df_pop=df.iloc[700:800,43]
df_reggae=df.iloc[800:900,43]
df_rock=df.iloc[900:,44]
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc14_mean")
plt.title("mfcc14_mean plots")
plt.show()

# %%
df_blues=df.iloc[:100,44]
df_classical=df.iloc[100:200,44]
df_country=df.iloc[200:300,44]
df_disco=df.iloc[300:400,44]
df_hiphop=df.iloc[400:500,44]
df_jazz=df.iloc[500:600,44]
df_metal=df.iloc[600:700,44]
df_pop=df.iloc[700:800,44]
df_reggae=df.iloc[800:900,44]
df_rock=df.iloc[900:,44]
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc14_var")
plt.title("mfcc14_var plots")
plt.show()

# %%
df_blues=df.iloc[:100,45]
df_classical=df.iloc[100:200,45]
df_country=df.iloc[200:300,45]
df_disco=df.iloc[300:400,45]
df_hiphop=df.iloc[400:500,45]
df_jazz=df.iloc[500:600,45]
df_metal=df.iloc[600:700,45]
df_pop=df.iloc[700:800,45]
df_reggae=df.iloc[800:900,45]
df_rock=df.iloc[900:,45]
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc15_mean")
plt.title("mfcc15_mean plots")
plt.show()

# %%
df_blues=df.iloc[:100,46]
df_classical=df.iloc[100:200,46]
df_country=df.iloc[200:300,46]
df_disco=df.iloc[300:400,46]
df_hiphop=df.iloc[400:500,46]
df_jazz=df.iloc[500:600,46]
df_metal=df.iloc[600:700,46]
df_pop=df.iloc[700:800,46]
df_reggae=df.iloc[800:900,46]
df_rock=df.iloc[900:,46]
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc15_var")
plt.title("mfcc15_var plots")
plt.show()

# %%
df_blues=df.iloc[:100,47]
df_classical=df.iloc[100:200,47]
df_country=df.iloc[200:300,47]
df_disco=df.iloc[300:400,47]
df_hiphop=df.iloc[400:500,47]
df_jazz=df.iloc[500:600,47]
df_metal=df.iloc[600:700,47]
df_pop=df.iloc[700:800,47]
df_reggae=df.iloc[800:900,47]
df_rock=df.iloc[900:,47]
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc16_mean")
plt.title("mfcc16_mean plots")
plt.show()

# %%
df_blues=df.iloc[:100,48]
df_classical=df.iloc[100:200,48]
df_country=df.iloc[200:300,48]
df_disco=df.iloc[300:400,48]
df_hiphop=df.iloc[400:500,48]
df_jazz=df.iloc[500:600,48]
df_metal=df.iloc[600:700,48]
df_pop=df.iloc[700:800,48]
df_reggae=df.iloc[800:900,48]
df_rock=df.iloc[900:,48]
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc16_var")
plt.title("mfcc16_var plots")
plt.show()

# %%
df_blues=df.iloc[:100,49]
df_classical=df.iloc[100:200,49]
df_country=df.iloc[200:300,49]
df_disco=df.iloc[300:400,49]
df_hiphop=df.iloc[400:500,49]
df_jazz=df.iloc[500:600,49]
df_metal=df.iloc[600:700,49]
df_pop=df.iloc[700:800,49]
df_reggae=df.iloc[800:900,49]
df_rock=df.iloc[900:,49]
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc17_mean")
plt.title("mfcc17_mean plots")
plt.show()

# %%
df_blues=df.iloc[:100,50]
df_classical=df.iloc[100:200,50]
df_country=df.iloc[200:300,50]
df_disco=df.iloc[300:400,50]
df_hiphop=df.iloc[400:500,50]
df_jazz=df.iloc[500:600,50]
df_metal=df.iloc[600:700,50]
df_pop=df.iloc[700:800,50]
df_reggae=df.iloc[800:900,50]
df_rock=df.iloc[900:,50]
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc17_var")
plt.title("mfcc17_var plots")
plt.show()

# %%
df_blues=df.iloc[:100,51]
df_classical=df.iloc[100:200,51]
df_country=df.iloc[200:300,51]
df_disco=df.iloc[300:400,51]
df_hiphop=df.iloc[400:500,51]
df_jazz=df.iloc[500:600,51]
df_metal=df.iloc[600:700,51]
df_pop=df.iloc[700:800,51]
df_reggae=df.iloc[800:900,51]
df_rock=df.iloc[900:,51]
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc18_mean")
plt.title("mfcc18_mean plots")
plt.show()

# %%
df_blues=df.iloc[:100,52]
df_classical=df.iloc[100:200,52]
df_country=df.iloc[200:300,52]
df_disco=df.iloc[300:400,52]
df_hiphop=df.iloc[400:500,52]
df_jazz=df.iloc[500:600,52]
df_metal=df.iloc[600:700,52]
df_pop=df.iloc[700:800,52]
df_reggae=df.iloc[800:900,52]
df_rock=df.iloc[900:,52]
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc18_var")
plt.title("mfcc18_var plots")
plt.show()

# %%
df_blues=df.iloc[:100,53]
df_classical=df.iloc[100:200,53]
df_country=df.iloc[200:300,53]
df_disco=df.iloc[300:400,53]
df_hiphop=df.iloc[400:500,53]
df_jazz=df.iloc[500:600,53]
df_metal=df.iloc[600:700,53]
df_pop=df.iloc[700:800,53]
df_reggae=df.iloc[800:900,53]
df_rock=df.iloc[900:,53]
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc19_mean")
plt.title("mfcc19_mean plots")
plt.show()

# %%
df_blues=df.iloc[:100,54]
df_classical=df.iloc[100:200,54]
df_country=df.iloc[200:300,54]
df_disco=df.iloc[300:400,54]
df_hiphop=df.iloc[400:500,54]
df_jazz=df.iloc[500:600,54]
df_metal=df.iloc[600:700,54]
df_pop=df.iloc[700:800,54]
df_reggae=df.iloc[800:900,54]
df_rock=df.iloc[900:,54]
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc19_var")
plt.title("mfcc19_var plots")
plt.show()

# %%
df_blues=df.iloc[:100,55]
df_classical=df.iloc[100:200,55]
df_country=df.iloc[200:300,55]
df_disco=df.iloc[300:400,55]
df_hiphop=df.iloc[400:500,55]
df_jazz=df.iloc[500:600,55]
df_metal=df.iloc[600:700,55]
df_pop=df.iloc[700:800,55]
df_reggae=df.iloc[800:900,55]
df_rock=df.iloc[900:,55]
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc20_mean")
plt.title("mfcc20_mean plots")
plt.show()

# %%
df_blues=df.iloc[:100,56]
df_classical=df.iloc[100:200,56]
df_country=df.iloc[200:300,56]
df_disco=df.iloc[300:400,56]
df_hiphop=df.iloc[400:500,56]
df_jazz=df.iloc[500:600,56]
df_metal=df.iloc[600:700,56]
df_pop=df.iloc[700:800,56]
df_reggae=df.iloc[800:900,56]
df_rock=df.iloc[900:,56]
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)

plt.xlabel("Labels")
plt.ylabel("mfcc20_var")
plt.title("mfcc20_var plots")
plt.show()

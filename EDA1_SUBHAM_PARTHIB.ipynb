# %% [markdown]
# <a href="https://colab.research.google.com/github/keshavisha/Music-Genre/blob/main/Music_Genre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Subham_From_(R->AF)**

# %%
df = pd.read_csv('features_30_sec.csv')

# %%
df_blues = df.iloc[:100,15]
df_classical = df.iloc[100:200, 15]
df_country = df.iloc[200:300, 15]
df_disco = df.iloc[300:400, 15]
df_hiphop = df.iloc[400:500, 15]
df_jazz = df.iloc[500:600, 15]
df_metal = df.iloc[600:700, 15]
df_pop = df.iloc[700:800, 15]
df_reggae = df.iloc[800:900, 15]
df_rock = df.iloc[900:, 15]

# %%
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("perceptr_var")
plt.title("perceptr_var plots")
# Out:
# Text(0.5, 1.0, 'perceptr_var plots')

# %%
df_blues = df.iloc[:100,16]
df_classical = df.iloc[100:200, 16]
df_country = df.iloc[200:300, 16]
df_disco = df.iloc[300:400, 16]
df_hiphop = df.iloc[400:500, 16]
df_jazz = df.iloc[500:600, 16]
df_metal = df.iloc[600:700, 16]
df_pop = df.iloc[700:800, 16]
df_reggae = df.iloc[800:900, 16]
df_rock = df.iloc[900:, 16]

# %%
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("tempo")
plt.title("tempo plots")
# Out:
# Text(0.5, 1.0, 'tempo plots')

# %%
df_blues = df.iloc[:100,17]
df_classical = df.iloc[100:200, 17]
df_country = df.iloc[200:300, 17]
df_disco = df.iloc[300:400, 17]
df_hiphop = df.iloc[400:500, 17]
df_jazz = df.iloc[500:600, 17]
df_metal = df.iloc[600:700, 17]
df_pop = df.iloc[700:800, 17]
df_reggae = df.iloc[800:900, 17]
df_rock = df.iloc[900:, 17]

# %%
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc1_mean")
plt.title("mfcc1_mean plots")
# Out:
# Text(0.5, 1.0, 'mfcc1_mean plots')

# %%
df_blues = df.iloc[:100,18]
df_classical = df.iloc[100:200, 18]
df_country = df.iloc[200:300, 18]
df_disco = df.iloc[300:400, 18]
df_hiphop = df.iloc[400:500, 18]
df_jazz = df.iloc[500:600, 18]
df_metal = df.iloc[600:700, 18]
df_pop = df.iloc[700:800, 18]
df_reggae = df.iloc[800:900, 18]
df_rock = df.iloc[900:, 18]

# %%
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc1_var")
plt.title("mfcc1_var plots")
# Out:
# Text(0.5, 1.0, 'mfcc1_var plots')

# %%
df_blues = df.iloc[:100,19]
df_classical = df.iloc[100:200, 19]
df_country = df.iloc[200:300, 19]
df_disco = df.iloc[300:400, 19]
df_hiphop = df.iloc[400:500, 19]
df_jazz = df.iloc[500:600, 19]
df_metal = df.iloc[600:700, 19]
df_pop = df.iloc[700:800, 19]
df_reggae = df.iloc[800:900, 19]
df_rock = df.iloc[900:, 19]

# %%
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc2_mean")
plt.title("mfcc2_mean plots")
# Out:
# Text(0.5, 1.0, 'mfcc2_mean plots')

# %%
df_blues = df.iloc[:100,20]
df_classical = df.iloc[100:200, 20]
df_country = df.iloc[200:300, 20]
df_disco = df.iloc[300:400, 20]
df_hiphop = df.iloc[400:500, 20]
df_jazz = df.iloc[500:600, 20]
df_metal = df.iloc[600:700, 20]
df_pop = df.iloc[700:800, 20]
df_reggae = df.iloc[800:900, 20]
df_rock = df.iloc[900:, 20]

# %%
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc2_var")
plt.title("mfcc2_var plots")
# Out:
# Text(0.5, 1.0, 'mfcc2_var plots')

# %%
df_blues = df.iloc[:100,21]
df_classical = df.iloc[100:200, 21]
df_country = df.iloc[200:300, 21]
df_disco = df.iloc[300:400, 21]
df_hiphop = df.iloc[400:500, 21]
df_jazz = df.iloc[500:600, 21]
df_metal = df.iloc[600:700, 21]
df_pop = df.iloc[700:800, 21]
df_reggae = df.iloc[800:900, 21]
df_rock = df.iloc[900:, 21]

# %%
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc3_mean")
plt.title("mfcc3_mean plots")
# Out:
# Text(0.5, 1.0, 'mfcc3_mean plots')

# %%
df_blues = df.iloc[:100,22]
df_classical = df.iloc[100:200, 22]
df_country = df.iloc[200:300, 22]
df_disco = df.iloc[300:400, 22]
df_hiphop = df.iloc[400:500, 22]
df_jazz = df.iloc[500:600, 22]
df_metal = df.iloc[600:700, 22]
df_pop = df.iloc[700:800, 22]
df_reggae = df.iloc[800:900, 22]
df_rock = df.iloc[900:, 22]

# %%
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc3_var")
plt.title("mfcc3_var plots")
# Out:
# Text(0.5, 1.0, 'mfcc3_var plots')

# %%
df_blues = df.iloc[:100,23]
df_classical = df.iloc[100:200, 23]
df_country = df.iloc[200:300, 23]
df_disco = df.iloc[300:400, 23]
df_hiphop = df.iloc[400:500, 23]
df_jazz = df.iloc[500:600, 23]
df_metal = df.iloc[600:700, 23]
df_pop = df.iloc[700:800, 23]
df_reggae = df.iloc[800:900, 23]
df_rock = df.iloc[900:, 23]

# %%
# mfcc4_mean
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc4_mean")
plt.title("mfcc4_mean plots")
# Out:
# Text(0.5, 1.0, 'mfcc4_mean plots')

# %%
df_blues = df.iloc[:100,24]
df_classical = df.iloc[100:200, 24]
df_country = df.iloc[200:300, 24]
df_disco = df.iloc[300:400, 24]
df_hiphop = df.iloc[400:500, 24]
df_jazz = df.iloc[500:600, 24]
df_metal = df.iloc[600:700, 24]
df_pop = df.iloc[700:800, 24]
df_reggae = df.iloc[800:900, 24]
df_rock = df.iloc[900:, 24]

# %%
# mfcc4_var
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc4_var")
plt.title("mfcc4_var plots")
# Out:
# Text(0.5, 1.0, 'mfcc4_var plots')

# %%
df_blues = df.iloc[:100,25]
df_classical = df.iloc[100:200, 25]
df_country = df.iloc[200:300, 25]
df_disco = df.iloc[300:400, 25]
df_hiphop = df.iloc[400:500, 25]
df_jazz = df.iloc[500:600, 25]
df_metal = df.iloc[600:700, 25]
df_pop = df.iloc[700:800, 25]
df_reggae = df.iloc[800:900, 25]
df_rock = df.iloc[900:, 25]

# %%
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc5_mean")
plt.title("mfcc5_mean plots")
# Out:
# Text(0.5, 1.0, 'mfcc5_mean plots')

# %%
df_blues = df.iloc[:100,26]
df_classical = df.iloc[100:200, 26]
df_country = df.iloc[200:300, 26]
df_disco = df.iloc[300:400, 26]
df_hiphop = df.iloc[400:500, 26]
df_jazz = df.iloc[500:600, 26]
df_metal = df.iloc[600:700, 26]
df_pop = df.iloc[700:800, 26]
df_reggae = df.iloc[800:900, 26]
df_rock = df.iloc[900:, 26]

# %%
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc5_var")
plt.title("mfcc5_var plots")
# Out:
# Text(0.5, 1.0, 'mfcc5_var plots')

# %%
df_blues = df.iloc[:100,27]
df_classical = df.iloc[100:200, 27]
df_country = df.iloc[200:300, 27]
df_disco = df.iloc[300:400, 27]
df_hiphop = df.iloc[400:500, 27]
df_jazz = df.iloc[500:600, 27]
df_metal = df.iloc[600:700, 27]
df_pop = df.iloc[700:800, 27]
df_reggae = df.iloc[800:900, 27]
df_rock = df.iloc[900:, 27]

# %%
# mfcc6_mean
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc6_mean")
plt.title("mfcc6_mean plots")
# Out:
# Text(0.5, 1.0, 'mfcc6_mean plots')

# %%
df_blues = df.iloc[:100,28]
df_classical = df.iloc[100:200, 28]
df_country = df.iloc[200:300, 28]
df_disco = df.iloc[300:400, 28]
df_hiphop = df.iloc[400:500, 28]
df_jazz = df.iloc[500:600, 28]
df_metal = df.iloc[600:700, 28]
df_pop = df.iloc[700:800, 28]
df_reggae = df.iloc[800:900, 28]
df_rock = df.iloc[900:, 28]

# %%
# mfcc6_var
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc6_var")
plt.title("mfcc6_var plots")
# Out:
# Text(0.5, 1.0, 'mfcc6_var plots')

# %%
df_blues = df.iloc[:100,29]
df_classical = df.iloc[100:200, 29]
df_country = df.iloc[200:300, 29]
df_disco = df.iloc[300:400, 29]
df_hiphop = df.iloc[400:500, 29]
df_jazz = df.iloc[500:600, 29]
df_metal = df.iloc[600:700, 29]
df_pop = df.iloc[700:800, 29]
df_reggae = df.iloc[800:900, 29]
df_rock = df.iloc[900:, 29]

# %%
# mfcc7_mean
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("mfcc7_mean")
plt.title("mfcc7_mean plots")
# Out:
# Text(0.5, 1.0, 'mfcc7_mean plots')

# %%
##########

# %% [markdown]
# **Total 15 columns done_Subham**

# %% [markdown]
# ***Parthib_From_(C to Q)***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_parthib = pd.read_csv('features_30_sec.csv')

# %%
df_blues = df_parthib.iloc[:100,0]
df_classical = df_parthib.iloc[100:200, 0]
df_country = df_parthib.iloc[200:300, 0]
df_disco = df_parthib.iloc[300:400, 0]
df_hiphop = df_parthib.iloc[400:500, 0]
df_jazz = df_parthib.iloc[500:600, 0]
df_metal = df_parthib.iloc[600:700, 0]
df_pop = df_parthib.iloc[700:800, 0]
df_reggae = df_parthib.iloc[800:900, 0]
df_rock = df_parthib.iloc[900:, 0]

# %%
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("chroma_stft_mean")
plt.title("chroma_stft_mean plots")
# Out:
# Text(0.5, 1.0, 'chroma_stft_mean plots')

# %%
df_blues = df_parthib.iloc[:100,1]
df_classical = df_parthib.iloc[100:200, 1]
df_country = df_parthib.iloc[200:300, 1]
df_disco = df_parthib.iloc[300:400, 1]
df_hiphop = df_parthib.iloc[400:500, 1]
df_jazz = df_parthib.iloc[500:600, 1]
df_metal = df_parthib.iloc[600:700, 1]
df_pop = df_parthib.iloc[700:800, 1]
df_reggae = df_parthib.iloc[800:900, 1]
df_rock = df_parthib.iloc[900:, 1]

# %%
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("chroma_stft_var")
plt.title("chroma_stft_var plots")
plt.show()

# %%
df_blues = df_parthib.iloc[:100,2]
df_classical = df_parthib.iloc[100:200, 2]
df_country = df_parthib.iloc[200:300, 2]
df_disco = df_parthib.iloc[300:400, 2]
df_hiphop = df_parthib.iloc[400:500, 2]
df_jazz = df_parthib.iloc[500:600, 2]
df_metal = df_parthib.iloc[600:700, 2]
df_pop = df_parthib.iloc[700:800, 2]
df_reggae = df_parthib.iloc[800:900, 2]
df_rock = df_parthib.iloc[900:, 2]

# %%
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("rms_mean")
plt.title("rms_mean plots")
# Out:
# Text(0.5, 1.0, 'rms_mean plots')

# %%
df_blues = df_parthib.iloc[:100,3]
df_classical = df_parthib.iloc[100:200, 3]
df_country = df_parthib.iloc[200:300, 3]
df_disco = df_parthib.iloc[300:400, 3]
df_hiphop = df_parthib.iloc[400:500, 3]
df_jazz = df_parthib.iloc[500:600, 3]
df_metal = df_parthib.iloc[600:700, 3]
df_pop = df_parthib.iloc[700:800, 3]
df_reggae = df_parthib.iloc[800:900, 3]
df_rock = df_parthib.iloc[900:, 3]

# %%
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("rms_var")
plt.title("rms_var plots")
# Out:
# Text(0.5, 1.0, 'rms_var plots')

# %%
df_blues = df_parthib.iloc[:100,4]
df_classical = df_parthib.iloc[100:200, 4]
df_country = df_parthib.iloc[200:300, 4]
df_disco = df_parthib.iloc[300:400, 4]
df_hiphop = df_parthib.iloc[400:500, 4]
df_jazz = df_parthib.iloc[500:600, 4]
df_metal = df_parthib.iloc[600:700, 4]
df_pop = df_parthib.iloc[700:800, 4]
df_reggae = df_parthib.iloc[800:900, 4]
df_rock = df_parthib.iloc[900:, 4]

# %%
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("spectral_centroid_mean")
plt.title("spectral_centroid_mean plots")
# Out:
# Text(0.5, 1.0, 'spectral_centroid_mean plots')

# %%
df_blues = df_parthib.iloc[:100,5]
df_classical = df_parthib.iloc[100:200, 5]
df_country = df_parthib.iloc[200:300, 5]
df_disco = df_parthib.iloc[300:400, 5]
df_hiphop = df_parthib.iloc[400:500, 5]
df_jazz = df_parthib.iloc[500:600, 5]
df_metal = df_parthib.iloc[600:700, 5]
df_pop = df_parthib.iloc[700:800, 5]
df_reggae = df_parthib.iloc[800:900, 5]
df_rock = df_parthib.iloc[900:, 5]

# %%
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("spectral_centroid_var")
plt.title("spectral_centroid_var plots")
# Out:
# Text(0.5, 1.0, 'spectral_centroid_var plots')

# %%
df_blues = df_parthib.iloc[:100,6]
df_classical = df_parthib.iloc[100:200, 6]
df_country = df_parthib.iloc[200:300, 6]
df_disco = df_parthib.iloc[300:400, 6]
df_hiphop = df_parthib.iloc[400:500, 6]
df_jazz = df_parthib.iloc[500:600, 6]
df_metal = df_parthib.iloc[600:700, 6]
df_pop = df_parthib.iloc[700:800, 6]
df_reggae = df_parthib.iloc[800:900, 6]
df_rock = df_parthib.iloc[900:, 6]

# %%
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("spectral_bandwidth_mean")
plt.title("spectral_bandwidth_mean plots")
# Out:
# Text(0.5, 1.0, 'spectral_bandwidth_mean plots')

# %%
df_blues = df_parthib.iloc[:100,7]
df_classical = df_parthib.iloc[100:200, 7]
df_country = df_parthib.iloc[200:300, 7]
df_disco = df_parthib.iloc[300:400, 7]
df_hiphop = df_parthib.iloc[400:500, 7]
df_jazz = df_parthib.iloc[500:600, 7]
df_metal = df_parthib.iloc[600:700, 7]
df_pop = df_parthib.iloc[700:800, 7]
df_reggae = df_parthib.iloc[800:900, 7]
df_rock = df_parthib.iloc[900:, 7]

# %%
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("spectral_bandwidth_var")
plt.title("spectral_bandwidth_var plots")
# Out:
# Text(0.5, 1.0, 'spectral_bandwidth_var plots')

# %%
df_blues = df_parthib.iloc[:100,8]
df_classical = df_parthib.iloc[100:200, 8]
df_country = df_parthib.iloc[200:300, 8]
df_disco = df_parthib.iloc[300:400, 8]
df_hiphop = df_parthib.iloc[400:500, 8]
df_jazz = df_parthib.iloc[500:600, 8]
df_metal = df_parthib.iloc[600:700, 8]
df_pop = df_parthib.iloc[700:800, 8]
df_reggae = df_parthib.iloc[800:900, 8]
df_rock = df_parthib.iloc[900:, 8]

# %%
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("rolloff_mean")
plt.title("rolloff_mean plots")
# Out:
# Text(0.5, 1.0, 'rolloff_mean plots')

# %%
df_blues = df_parthib.iloc[:100,9]
df_classical = df_parthib.iloc[100:200, 9]
df_country = df_parthib.iloc[200:300, 9]
df_disco = df_parthib.iloc[300:400, 9]
df_hiphop = df_parthib.iloc[400:500, 9]
df_jazz = df_parthib.iloc[500:600, 9]
df_metal = df_parthib.iloc[600:700, 9]
df_pop = df_parthib.iloc[700:800, 9]
df_reggae = df_parthib.iloc[800:900, 9]
df_rock = df_parthib.iloc[900:, 9]

# %%
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("rolloff_var")
plt.title("rolloff_var plots")
# Out:
# Text(0.5, 1.0, 'rolloff_var plots')

# %%
df_blues = df_parthib.iloc[:100,10]
df_classical = df_parthib.iloc[100:200, 10]
df_country = df_parthib.iloc[200:300, 10]
df_disco = df_parthib.iloc[300:400, 10]
df_hiphop = df_parthib.iloc[400:500, 10]
df_jazz = df_parthib.iloc[500:600, 10]
df_metal = df_parthib.iloc[600:700, 10]
df_pop = df_parthib.iloc[700:800, 10]
df_reggae = df_parthib.iloc[800:900, 10]
df_rock = df_parthib.iloc[900:, 10]

# %%
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("zero_crossing_rate_mean")
plt.title("zero_crossing_rate_mean plots")
# Out:
# Text(0.5, 1.0, 'zero_crossing_rate_mean plots')

# %%
df_blues = df_parthib.iloc[:100,11]
df_classical = df_parthib.iloc[100:200, 11]
df_country = df_parthib.iloc[200:300, 11]
df_disco = df_parthib.iloc[300:400, 11]
df_hiphop = df_parthib.iloc[400:500, 11]
df_jazz = df_parthib.iloc[500:600, 11]
df_metal = df_parthib.iloc[600:700, 11]
df_pop = df_parthib.iloc[700:800, 11]
df_reggae = df_parthib.iloc[800:900, 11]
df_rock = df_parthib.iloc[900:, 11]

# %%
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("zero_crossing_rate_var")
plt.title("zero_crossing_rate_var plots")
# Out:
# Text(0.5, 1.0, 'zero_crossing_rate_var plots')

# %%
df_blues = df_parthib.iloc[:100,12]
df_classical = df_parthib.iloc[100:200, 12]
df_country = df_parthib.iloc[200:300, 12]
df_disco = df_parthib.iloc[300:400, 12]
df_hiphop = df_parthib.iloc[400:500, 12]
df_jazz = df_parthib.iloc[500:600, 12]
df_metal = df_parthib.iloc[600:700, 12]
df_pop = df_parthib.iloc[700:800, 12]
df_reggae = df_parthib.iloc[800:900, 12]
df_rock = df_parthib.iloc[900:, 12]

# %%
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("harmony_mean")
plt.title("harmony_mean plots")
# Out:
# Text(0.5, 1.0, 'harmony_mean plots')

# %%
df_blues = df_parthib.iloc[:100,13]
df_classical = df_parthib.iloc[100:200, 13]
df_country = df_parthib.iloc[200:300, 13]
df_disco = df_parthib.iloc[300:400, 13]
df_hiphop = df_parthib.iloc[400:500, 13]
df_jazz = df_parthib.iloc[500:600, 13]
df_metal = df_parthib.iloc[600:700, 13]
df_pop = df_parthib.iloc[700:800, 13]
df_reggae = df_parthib.iloc[800:900, 13]
df_rock = df_parthib.iloc[900:, 13]

# %%
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("harmony_var")
plt.title("harmony_var plots")
# Out:
# Text(0.5, 1.0, 'harmony_var plots')

# %%
df_blues = df_parthib.iloc[:100,14]
df_classical = df_parthib.iloc[100:200, 14]
df_country = df_parthib.iloc[200:300, 14]
df_disco = df_parthib.iloc[300:400, 14]
df_hiphop = df_parthib.iloc[400:500, 14]
df_jazz = df_parthib.iloc[500:600, 14]
df_metal = df_parthib.iloc[600:700, 14]
df_pop = df_parthib.iloc[700:800, 14]
df_reggae = df_parthib.iloc[800:900, 14]
df_rock = df_parthib.iloc[900:, 14]

# %%
plt.scatter([1]*(len(df_blues)),df_blues)
plt.scatter([2]*(len(df_classical)),df_classical)
plt.scatter([3]*(len(df_country)),df_country)
plt.scatter([4]*(len(df_disco)),df_disco)
plt.scatter([5]*(len(df_hiphop)),df_hiphop)
plt.scatter([6]*(len(df_jazz)),df_jazz)
plt.scatter([7]*(len(df_metal)),df_metal)
plt.scatter([8]*(len(df_pop)),df_pop)
plt.scatter([9]*(len(df_reggae)),df_reggae)
plt.scatter([10]*(len(df_rock)),df_rock)
plt.xlabel("Labels")
plt.ylabel("perceptr_mean")
plt.title("perceptr_mean plots")
# Out:
# Text(0.5, 1.0, 'perceptr_mean plots')

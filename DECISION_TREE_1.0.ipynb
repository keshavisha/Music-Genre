# %% [markdown]
# <a href="https://colab.research.google.com/github/keshavisha/Music-Genre/blob/main/DECISION_TREE_1.0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("features_30_sec.csv")
data=df.iloc[:,2:-1]
labels=df.iloc[:,-1]
from sklearn import tree

# %%
model=tree.DecisionTreeClassifier(random_state=100,max_depth=3)
model.fit(data,labels)
tree.plot_tree(model)
# Out:
# [Text(0.5, 0.875, 'x[15] <= 0.0\ngini = 0.9\nsamples = 1000\nvalue = [100, 100, 100, 100, 100, 100, 100, 100, 100, 100]'),
#  Text(0.25, 0.625, 'x[9] <= 1649228.0\ngini = 0.423\nsamples = 109\nvalue = [0, 80, 3, 1, 0, 21, 0, 1, 1, 2]'),
#  Text(0.125, 0.375, 'x[1] <= 0.09\ngini = 0.19\nsamples = 86\nvalue = [0, 77, 0, 1, 0, 8, 0, 0, 0, 0]'),
#  Text(0.0625, 0.125, 'gini = 0.077\nsamples = 75\nvalue = [0, 72, 0, 0, 0, 3, 0, 0, 0, 0]'),
#  Text(0.1875, 0.125, 'gini = 0.579\nsamples = 11\nvalue = [0, 5, 0, 1, 0, 5, 0, 0, 0, 0]'),
#  Text(0.375, 0.375, 'x[45] <= -0.802\ngini = 0.635\nsamples = 23\nvalue = [0, 3, 3, 0, 0, 13, 0, 1, 1, 2]'),
#  Text(0.3125, 0.125, 'gini = 0.806\nsamples = 12\nvalue = [0, 3, 3, 0, 0, 2, 0, 1, 1, 2]'),
#  Text(0.4375, 0.125, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 0, 0, 11, 0, 0, 0, 0]'),
#  Text(0.75, 0.625, 'x[0] <= 0.422\ngini = 0.893\nsamples = 891\nvalue = [100, 20, 97, 99, 100, 79, 100, 99, 99, 98]'),
# ...

# %%
model=tree.DecisionTreeClassifier(random_state=100,max_depth=5)
model.fit(data,labels)
tree.plot_tree(model)
# Out:
# [Text(0.40555555555555556, 0.9166666666666666, 'x[15] <= 0.0\ngini = 0.9\nsamples = 1000\nvalue = [100, 100, 100, 100, 100, 100, 100, 100, 100, 100]'),
#  Text(0.16666666666666666, 0.75, 'x[9] <= 1649228.0\ngini = 0.423\nsamples = 109\nvalue = [0, 80, 3, 1, 0, 21, 0, 1, 1, 2]'),
#  Text(0.08888888888888889, 0.5833333333333334, 'x[1] <= 0.09\ngini = 0.19\nsamples = 86\nvalue = [0, 77, 0, 1, 0, 8, 0, 0, 0, 0]'),
#  Text(0.044444444444444446, 0.4166666666666667, 'x[14] <= 0.0\ngini = 0.077\nsamples = 75\nvalue = [0, 72, 0, 0, 0, 3, 0, 0, 0, 0]'),
#  Text(0.022222222222222223, 0.25, 'gini = 0.0\nsamples = 67\nvalue = [0, 67, 0, 0, 0, 0, 0, 0, 0, 0]'),
#  Text(0.06666666666666667, 0.25, 'x[13] <= 0.002\ngini = 0.469\nsamples = 8\nvalue = [0, 5, 0, 0, 0, 3, 0, 0, 0, 0]'),
#  Text(0.044444444444444446, 0.08333333333333333, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0, 0, 0, 0, 0, 0, 0]'),
# ...

# %%
model=tree.DecisionTreeClassifier(random_state=100,max_depth=10)
model.fit(data,labels)
tree.plot_tree(model)
# Out:
# [Text(0.34730113636363635, 0.9545454545454546, 'x[15] <= 0.0\ngini = 0.9\nsamples = 1000\nvalue = [100, 100, 100, 100, 100, 100, 100, 100, 100, 100]'),
#  Text(0.0427807486631016, 0.8636363636363636, 'x[9] <= 1649228.0\ngini = 0.423\nsamples = 109\nvalue = [0, 80, 3, 1, 0, 21, 0, 1, 1, 2]'),
#  Text(0.0213903743315508, 0.7727272727272727, 'x[1] <= 0.09\ngini = 0.19\nsamples = 86\nvalue = [0, 77, 0, 1, 0, 8, 0, 0, 0, 0]'),
#  Text(0.0106951871657754, 0.6818181818181818, 'x[14] <= 0.0\ngini = 0.077\nsamples = 75\nvalue = [0, 72, 0, 0, 0, 3, 0, 0, 0, 0]'),
#  Text(0.0053475935828877, 0.5909090909090909, 'gini = 0.0\nsamples = 67\nvalue = [0, 67, 0, 0, 0, 0, 0, 0, 0, 0]'),
#  Text(0.016042780748663103, 0.5909090909090909, 'x[13] <= 0.002\ngini = 0.469\nsamples = 8\nvalue = [0, 5, 0, 0, 0, 3, 0, 0, 0, 0]'),
#  Text(0.0106951871657754, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0, 0, 0, 0, 0, 0, 0]'),
# ...

# %%
model=tree.DecisionTreeClassifier(random_state=100,max_depth=15)
model.fit(data,labels)
tree.plot_tree(model)
# Out:
# [Text(0.3643347966205738, 0.96875, 'x[15] <= 0.0\ngini = 0.9\nsamples = 1000\nvalue = [100, 100, 100, 100, 100, 100, 100, 100, 100, 100]'),
#  Text(0.03308348410441975, 0.90625, 'x[9] <= 1649228.0\ngini = 0.423\nsamples = 109\nvalue = [0, 80, 3, 1, 0, 21, 0, 1, 1, 2]'),
#  Text(0.016541742052209873, 0.84375, 'x[1] <= 0.09\ngini = 0.19\nsamples = 86\nvalue = [0, 77, 0, 1, 0, 8, 0, 0, 0, 0]'),
#  Text(0.008270871026104937, 0.78125, 'x[14] <= 0.0\ngini = 0.077\nsamples = 75\nvalue = [0, 72, 0, 0, 0, 3, 0, 0, 0, 0]'),
#  Text(0.004135435513052468, 0.71875, 'gini = 0.0\nsamples = 67\nvalue = [0, 67, 0, 0, 0, 0, 0, 0, 0, 0]'),
#  Text(0.012406306539157405, 0.71875, 'x[13] <= 0.002\ngini = 0.469\nsamples = 8\nvalue = [0, 5, 0, 0, 0, 3, 0, 0, 0, 0]'),
#  Text(0.008270871026104937, 0.65625, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0, 0, 0, 0, 0, 0, 0]'),
#  Text(0.016541742052209873, 0.65625, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 3, 0, 0, 0, 0]'),
# ...
